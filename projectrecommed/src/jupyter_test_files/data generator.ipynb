# %%
# from faker import Faker
# import random
# import pandas as pd
from faker import Faker
import csv
import random
import pandas as pd

# class generateuserFake():
#     def Fake(self):
#         self.id = 1
#         self.fake = Faker ()
#         self.interest = ['python','JS','QA','PHP']
#         self.qualification = ['Bachelors','+2','Masters']
#         self.level = ['Entry','Mid','Senior']
#         self.companylist = ['Leapfrog','Aayulogic','Deerwalk', 'F1soft']
#         self.labels = ['Userid','Age','Interest','Qualification','Experience','Level','Company']
#         self.data = pd.DataFrame(columns=self.labels, index=None)
#         for i in range(10):
#             row = []
#             row.append(self.id)
#             row.append(random.randint(20,45))
#             self.f_interest= random.choice(self.interest)
#             row.append(self.f_interest)
#             row.append(random.choice(self.qualification))
#             row.append(random.randint(0,5))
#             if row[4]==0:
#                 self.f_level= self.level[0]
#                 row.append(self.f_level)
#             elif row[4]<=2:
#                 self.f_level= self.level[1]
#                 row.append(self.f_level)
#             else:
#                 self.f_level= self.level[2]
#                 row.append(self.f_level)
#             self.id += 1
            
#             row.append(random.choice(self.companylist))
#             self.data.loc[i]= row
#         return(self.data)
# if __name__ == '__main__':
# fak = generateFake()
# df=fak.Fake()
# df.set_index('Id',inplace=True)
#df.to_csv('src/data/data.csv', sep=',')


class generatejobFake():
    def Fake(self):
        self.id = 1
        self.fake = Faker ()
        self.interest = ['python','JS','QA','PHP']
        self.qualification = ['Bachelors','+2','Masters']
        self.level = ['Entry','Mid','Senior']
        # self.companylist = ['Leapfrog','Aayulogic','Deerwalk', 'F1soft']
        self.labels = ['Jobid','Age','Interest','Qualification','Experience','Level']
        self.data = pd.DataFrame(columns=self.labels, index=None)
        for i in range(20):
            row = []
            row.append(self.id)
            row.append(random.randint(20,45))
            self.f_interest= random.choice(self.interest)
            row.append(self.f_interest)
            row.append(random.choice(self.qualification))
            row.append(random.randint(0,5))
            if row[4]==0: # if experience 0 then level is lavel[0] that is entry level
                self.f_level= self.level[0]
                row.append(self.f_level)
            elif row[4]<=2:
                self.f_level= self.level[1]
                row.append(self.f_level)
            else:
                self.f_level= self.level[2]
                row.append(self.f_level)
            self.id += 1
            
            # row.append(random.choice(self.companylist))
            self.data.loc[i]= row # append each row to dataframe
        # print(self.data)
        return(self.data)


# fak_usr = generateuserFake()
# df_usr=fak_usr.Fake()
# df_usr.set_index('Userid',inplace=True)
# print(df_usr)

fak_comp = generatejobFake()
df_comp=fak_comp.Fake()
df_comp.set_index('Jobid',inplace=True)
df_comp.to_csv('jobdata.csv')
print(df_comp)
# Out:
#         Age Interest Qualification  Experience   Level
# Jobid
# 1.0    32.0   python       Masters         2.0     Mid
# 2.0    44.0       QA            +2         2.0     Mid
# 3.0    23.0       JS     Bachelors         0.0   Entry
# 4.0    39.0       JS            +2         4.0  Senior
# 5.0    42.0   python       Masters         4.0  Senior
# 6.0    35.0       QA       Masters         4.0  Senior
# 7.0    36.0       JS     Bachelors         4.0  Senior
# 8.0    44.0   python       Masters         4.0  Senior
# 9.0    31.0       QA     Bachelors         1.0     Mid
# 10.0   24.0      PHP            +2         5.0  Senior
# 11.0   20.0      PHP     Bachelors         0.0   Entry
# 12.0   30.0       JS     Bachelors         1.0     Mid
# 13.0   42.0       JS            +2         5.0  Senior
# 14.0   33.0       JS       Masters         5.0  Senior
# 15.0   45.0       JS     Bachelors         0.0   Entry
# 16.0   22.0   python     Bachelors         2.0     Mid
# 17.0   21.0       JS       Masters         4.0  Senior
# 18.0   31.0       JS            +2         0.0   Entry
# 19.0   44.0   python     Bachelors         3.0  Senior
# 20.0   28.0      PHP            +2         1.0     Mid
